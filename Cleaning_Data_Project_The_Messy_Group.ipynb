# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint

pd.set_option('display.max_columns', None)

#import geopandas as gpd
#from geopy.exc import GeocoderTimedOut 
#from geopy.geocoders import Nominatim 
#from opencage.geocoder import OpenCageGeocode

#key = 'e7fc4f62e32840878a466fb71e2ebda1'
#geocoder = OpenCageGeocode(key)

import re
import sklearn

# %%
df = pd.read_csv('alldata.csv')

# %%
df.shape
# Out:
# (6964, 5)

# %%
# check if dataframe has NaN
df.isna().sum()
# Out:
# position         11
# company          11
# description      11
# reviews        1638
# location         11
# dtype: int64

# %%
# remove NaN rows
df = df[df['position'].notna()]

# %%
# check that all NaN are gone
df.isna().sum()
# Out:
# position          0
# company           0
# description       0
# reviews        1627
# location          0
# dtype: int64

# %%
#split location into state and city
df[['City', 'State']] = df['location'].str.split(',', 1, expand=True)

# %%
#make new column for zip code
df['Zip-code']=df.location.str.extract('(\d+)')

# %%
# delete numbers in State
df['State'] = df['State'].str.replace('\d+', '')

# %%
#delete original location column
df.drop(['location'], axis=1)
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# 6959                            NetApp
# 6960  Pharmacyclics, an Abbvie Company
# 6961                          Oath Inc
# 6962                         Microsoft
# 6963                           Comcast
#
#                                             description  reviews       City  \
# 0     Development Director\nALS Therapy Development ...      NaN    Atlanta
# 1     Job Description\n\n"The road that leads to acc...      NaN    Atlanta
# 2     Growing company located in the Atlanta, GA are...      NaN    Atlanta
# 3     DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0    Atlanta
# 4     DESCRIPTION\nThe Emory University Department o...    550.0    Atlanta
# ...                                                 ...      ...        ...
# 6959  Are you data-driven? We at NetApp believe in t...    574.0  Sunnyvale
# 6960  Pharmacyclics is committed to the development ...     26.0  Sunnyvale
# 6961  Oath, a subsidiary of Verizon, is a values-led...      5.0  Sunnyvale
# 6962  We are the Bing Core Relevance team responsibl...   4618.0  Sunnyvale
# 6963  Comcast’s Technology &amp; Product organizatio...  11610.0  Sunnyvale
#
#       State Zip-code
# 0      GA      30301
# 1        GA      NaN
# 2        GA      NaN
# 3      GA      30303
# 4        GA      NaN
# ...     ...      ...
# 6959     CA      NaN
# 6960     CA      NaN
# 6961     CA      NaN
# 6962     CA      NaN
# 6963    CA     94089
#
# [6953 rows x 7 columns]

# %%
#deleting the old 'location' column
df=df.drop(columns=['location'])

# %%
# rename state with initials
df['State'] = df['State'].str.replace('^ +| +$', '')

# %%
#replace NaN with 0 in reviews
df['reviews']=df['reviews'].fillna(0)

# %%
# checking what kind of words to look for to extract seniority
df[df['position'].str.contains("Senior").fillna(False)]
# Out:
#                                                position  \
# 9     Senior Associate - Cognitive Data Scientist Na...
# 12                     Senior Associate, Data Scientist
# 16    Senior Structural Engineer-Transmission & Dist...
# 17                Senior Mobile Developer (iOS/Android)
# 20                           Senior Electrical Engineer
# ...                                                 ...
# 6915  Senior/Staff Full Stack Engineer - Advertising...
# 6916                    Senior Manager, Cost Accounting
# 6923                              Senior Data Scientist
# 6958                   Senior Data Scientist (GEC11902)
# 6962                    Senior Data & Applied Scientist
#
#                                company  \
# 9                                 KPMG
# 12                                KPMG
# 16                   Burns & McDonnell
# 17                          Perficient
# 20                   Burns & McDonnell
# ...                                ...
# 6915                 Walmart eCommerce
# 6916  Pharmacyclics, an Abbvie Company
# 6923                  Castlight Health
# 6958                           Walmart
# 6962                         Microsoft
#
#                                             description   reviews       City  \
# 9     Known for being a great place to work and buil...    4494.0    Atlanta
# 12    Innovate. Collaborate. Shine. Lighthouse — KPM...    4494.0    Atlanta
# 16    Description\nExecutes complex assignments requ...     152.0    Atlanta
# 17    Overview\n\n\n\nAt Perficient you’ll deliver m...      44.0    Atlanta
# 20    Description\nBurns &amp; McDonnell is consider...     152.0    Atlanta
# ...                                                 ...       ...        ...
# 6915  Position Description\nWe are seeking talented ...     141.0  Sunnyvale
# 6916  Pharmacyclics is committed to the development ...      26.0  Sunnyvale
# 6923  We’re hiring data scientists for a team of dat...       7.0  Sunnyvale
# 6958  Position Description\nProficient in Java or Py...  148114.0  Sunnyvale
# 6962  We are the Bing Core Relevance team responsibl...    4618.0  Sunnyvale
#
#      State Zip-code
# 9       GA    30338
# 12      GA    30338
# 16      GA    30309
# 17      GA    30338
# 20      GA    30309
# ...    ...      ...
# 6915    CA      NaN
# 6916    CA      NaN
# 6923    CA    94086
# 6958    CA    94086
# 6962    CA      NaN
#
# [1039 rows x 7 columns]

# %%
#isolating the different levels of seniority
df.loc[df['position'].str.contains('Junior|Jr|junior|jr', case=False), 'seniority'] = 'junior'
df.loc[df['position'].str.contains('Senior|Sr|senior|sr', case=False), 'seniority'] = 'senior'
df.loc[df['position'].str.contains('Entry|entry', case=False), 'seniority'] = 'entry level'

df.seniority.value_counts()
# Out:
# senior         1486
# junior           49
# entry level      17
# Name: seniority, dtype: int64

# %%
#isolating the different role types
df.loc[df['position'].str.contains('Scientist|scientist|science|Science', case=False), 'role'] = 'data scientist'
df.loc[df['position'].str.contains('Analyst|analyst', case=False), 'role'] = 'data analyst'
df.loc[df['position'].str.contains('Engineer|engineer|Engineering|engineering', case=False), 'role'] = 'data engineer'
df.loc[df['position'].str.contains('Developer|developer', case=False), 'role'] = 'developer'
df.loc[df['position'].str.contains('Manager|manager', case=False), 'role'] = 'manager'
df.loc[df['position'].str.contains('Director|director', case=False), 'role'] = 'director'


df.role.value_counts()
# Out:
# data scientist    2499
# data engineer     1294
# data analyst       852
# manager            549
# director           261
# developer          128
# Name: role, dtype: int64

# %%
# checking how many NaN these columns have (too many)
df.isna().sum()
# Out:
# position          0
# company           0
# description       0
# reviews        1627
# location          0
# seniority      5401
# role           1370
# dtype: int64

# %% [markdown]
# ### What should we do with fields that have more than one of these terms?
# #### For example 'Data science and analytics'

# %%
# create columns for each skills that could be found in the description
df['sql'] = np.where(df['description'].str.contains('SQL'or'sql'),'sql','')
df['python'] = np.where(df['description'].str.contains('python'or'Python'or'PYTHON'),'python','')
df['R'] = np.where(df['description'].str.contains('R'),'R','')
#df['C++'] = np.where(df['description'].str.contains('C++'or'c++''),"c++",'')
df['ML'] = np.where(df['description'].str.contains('machine learning'or'Machine learning'or'Machine Learning'or'ML'),'ML','')
df.python.value_counts()

# %%
# concatenate all these columns into one names skills
df['skills']=df['sql']+' ,'+df['python']+' ,'+df['R']+' ,'+df['ML']

# %%
df['skills'] = df[['sql', 'python','R','ML']].agg(','.join, axis=1)
df
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# 6959                            NetApp
# 6960  Pharmacyclics, an Abbvie Company
# 6961                          Oath Inc
# 6962                         Microsoft
# 6963                           Comcast
#
#                                             description  reviews  \
# 0     Development Director\nALS Therapy Development ...      NaN
# 1     Job Description\n\n"The road that leads to acc...      NaN
# 2     Growing company located in the Atlanta, GA are...      NaN
# 3     DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4     DESCRIPTION\nThe Emory University Department o...    550.0
# ...                                                 ...      ...
# 6959  Are you data-driven? We at NetApp believe in t...    574.0
# 6960  Pharmacyclics is committed to the development ...     26.0
# 6961  Oath, a subsidiary of Verizon, is a values-led...      5.0
# 6962  We are the Bing Core Relevance team responsibl...   4618.0
# 6963  Comcast’s Technology &amp; Product organizatio...  11610.0
#
#                  location seniority            role  sql python  R  ML  \
# 0      Atlanta, GA 30301        NaN        director              R
# 1             Atlanta, GA       NaN  data scientist              R
# 2             Atlanta, GA       NaN  data scientist  sql         R
# 3      Atlanta, GA 30303        NaN    data analyst  sql         R
# 4             Atlanta, GA       NaN             NaN              R  ML
# ...                   ...       ...             ...  ...    ... ..  ..
# 6959        Sunnyvale, CA       NaN       developer  sql         R  ML
# 6960        Sunnyvale, CA       NaN  data scientist              R
# 6961        Sunnyvale, CA       NaN  data scientist  sql         R  ML
# 6962        Sunnyvale, CA    senior  data scientist              R  ML
# 6963  Sunnyvale, CA 94089       NaN  data scientist  sql         R  ML
#
#          skills
# 0          ,,R,
# 1          ,,R,
# 2       sql,,R,
# 3       sql,,R,
# 4        ,,R,ML
# ...         ...
# 6959  sql,,R,ML
# 6960       ,,R,
# 6961  sql,,R,ML
# 6962     ,,R,ML
# 6963  sql,,R,ML
#
# [6953 rows x 12 columns]

# %%
# extract the education level from the description field
def CleanDescriptionQual (x):
    if 'bsc' in x.lower():
        return 'Bachelor'
    elif 'bachelor' in x.lower():
        return 'Bachelor'
    elif 'msc' in x.lower():
        return 'Masters'
    elif 'masters' in x.lower():
        return 'Masters'
    elif 'master' in x.lower():
        return 'Masters'
    elif 'phd' in x.lower():
        return 'PhD'
    else:
        return 'Not specified'
    
df['education'] = df['description'].apply(CleanDescriptionQual)

# %%
df
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# 6959                            NetApp
# 6960  Pharmacyclics, an Abbvie Company
# 6961                          Oath Inc
# 6962                         Microsoft
# 6963                           Comcast
#
#                                             description  reviews       City  \
# 0     Development Director\nALS Therapy Development ...      0.0    Atlanta
# 1     Job Description\n\n"The road that leads to acc...      0.0    Atlanta
# 2     Growing company located in the Atlanta, GA are...      0.0    Atlanta
# 3     DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0    Atlanta
# 4     DESCRIPTION\nThe Emory University Department o...    550.0    Atlanta
# ...                                                 ...      ...        ...
# 6959  Are you data-driven? We at NetApp believe in t...    574.0  Sunnyvale
# 6960  Pharmacyclics is committed to the development ...     26.0  Sunnyvale
# 6961  Oath, a subsidiary of Verizon, is a values-led...      5.0  Sunnyvale
# 6962  We are the Bing Core Relevance team responsibl...   4618.0  Sunnyvale
# 6963  Comcast’s Technology &amp; Product organizatio...  11610.0  Sunnyvale
#
#      State Zip-code seniority      education
# 0       GA    30301       NaN       Bachelor
# 1       GA      NaN       NaN        Masters
# 2       GA      NaN       NaN        Masters
# 3       GA    30303       NaN       Bachelor
# 4       GA      NaN       NaN            PhD
# ...    ...      ...       ...            ...
# 6959    CA      NaN       NaN       Bachelor
# 6960    CA      NaN       NaN       Bachelor
# 6961    CA      NaN       NaN            PhD
# 6962    CA      NaN    senior  Not specified
# 6963    CA    94089       NaN       Bachelor
#
# [6953 rows x 9 columns]

# %%
df.to_csv(r'cleandata.csv', index = False)
